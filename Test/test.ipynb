# %%
import re, pandas as pd
from sqlalchemy import create_engine
import sqlalchemy

text = 'sample_1999.zip'
found = re.search(r'sample_(.+?).zip', text).group(1)
print(found)
# Out:
# 1999

# %%
# downloads_filePath = "downloads/historical_data1_Q12005.txt" 
# downloads_filePath = "downloads/sample_svcg_1999.txt"
# cleaned_filePath = "cleaned/cleaned_historical_data1_Q12005.csv"

#   # LOAD AND ADD HEADERS TO THE PERFORMANCE DATA
# chunk = 500000
# csv_database = create_engine('sqlite:///csv_database.db')
# # i = 0
# # j = 1  
# # for performance in pd.read_csv(downloads_filePath, sep="|", header = None, chunksize = chunk, iterator = True, names = ["LOAN SEQUENCE NUMBER", \
# # "MONTHLY REPORTING PERIOD", \
# # "CURRENT ACTUAL UPB", \
# # "CURRENT LOAN DELINQUENCY STATUS",\
# # "LOAN AGE",\
# # "REMAINING MONTHS TO LEGAL MATURITY",\
# # "REPURCHASE FLAG",\
# # "MODIFICATION FLAG",\
# # "ZERO BALANCE CODE",\
# # "ZERO BALANCE EFFECTIVE DATE",\
# # "CURRENT INTEREST RATE",\
# # "CURRENT DEFERRED UPB",\
# # "DUE DATE OF LAST PAID INSTALLMENT",\
# # "MI RECOVERIES",\
# # "NET SALES PROCEEDS",\
# # "NON MI RECOVERIES",\
# # "EXPENSES",\
# # "LEGAL COSTS",\
# # "MAINTENANCE AND PRESERVATION COSTS",\
# # "TAXES AND INSURANCE",\
# # "MISCELLANEOUS EXPENSES",\
# # "ACTUAL LOSS CALCULATION",\
# # "MODIFICATION COST"\
# #      ]):

# #     performance.index += j
# #     i+=1
# #     performance.to_sql('table', csv_database, if_exists='append')
# #     j = performance.index[-1] + 1
# #     print(performance.shape)
# # # # CLEAN THE PERFORMANCE FILE
# # #     print(performance.shape)
# # # # NEEDS A CONDITIONAL FUNCTION FOR YEAR 2000
# # # # performance.index += j
# # # # i+=1


# # #     try:
# # #         perf = pd.concat([perf, performance])
# # #     except:
# # #         perf = performance
    
# # # print (perf.shape)
# # # print(perf[0:4])
# # foo_col = sqlalchemy.sql.column('LOAN SEQUENCE NUMBER')
# # df = sqlalchemy.sql.select(['*']).where(foo_col == 'F199Q1000012')

# # conn = csv_database.connect()
# # result = conn.execute("select * from table")
# df = pd.read_sql_query('SELECT `LOAN SEQUENCE NUMBER`, count(*) '
#                        'FROM `table` group by (`LOAN SEQUENCE NUMBER`) ', csv_database)

# print(df.shape)

# %%
df = pd.read_csv("cleaned_sample_orig_1999_test.csv")
print (df)

df = None
# Out:
#        CREDIT SCORE  FIRST PAYMENT DATE FIRST TIME HOMEBUYER FLAG  \
# 0               799              199903                         N
# 1               635              200212                         N
# 2               787              199905                         N
# 3               726              199904                         N
# 4               748              199905                         X
# 5               720              199905                         X
# 6               695              199905                         X
# 7               703              199905                         N
# 8               737              199903                         N
# 9               594              199903                         X
# 10              683              199905                         X
# 11              775              199905                         Y
# 12              749              199905                         N
# ...
