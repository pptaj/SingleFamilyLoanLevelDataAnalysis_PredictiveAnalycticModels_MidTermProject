# %%
import os, sys
import re
import pandas as pd
import numpy as np
import logging, sys, time
 
dir_path = "Files2"
ls_dir = os.listdir(dir_path)
filePath = dir_path + file

#Going into the Cleaned Files Directory
dir_path += "/Cleaned_Files/"
ls_dir = os.listdir(dir_path)

# Looping over all cleaned csv files and summarizing the data
x = 24
for file in ls_dir:   
    regexp = re.compile(r'.csv')
    x += 6

fileData = pd.read_csv("C://Users/taj/Desktop/cleaned_sample_orig_1999.csv")
    
#Looking only for csv files in the directory
if(regexp.search(file)):
    filePath = dir_path + file
    #fileData = pd.read_csv(filePath,header = 0)
    

def create_directory(dir_name):
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
        
# Saving dataframe to csv
def saveToCsv(dataframe, filePath, summaryParam):
    fp = re.split('/', filePath, flags=re.IGNORECASE)
    directory = fp[0] + "/" + fp[1]  + "/" 
    directory += "Summary"
    create_directory(directory)
    new_file_path = directory + "/" + summaryParam + "_" + fp[2]
    dataframe.to_csv(new_file_path, sep=',')
        
def summary_sum_originalUPB_per_year_func(fileData,filePath):
#Sum of Original UPB per year
    d= pd.DataFrame({'sum of UPB per year' : fileData.groupby(["ORIGINATION YEAR"])["ORIGINAL UPB"].sum()}).reset_index()
    print(d)
    try:
        saveToCsv(d, filePath, "Sum_OriginalUPB_Per_Year")
    except:
        print("Sum of Original UPB summary file couldn't be saved. Permission Denied Exception")
        pass
    
def summary_sum_originalUPB_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Sum of UPB per Quarter' : fileData.groupby(["ORIGINATION QUARTER"])["ORIGINAL UPB"].sum()}).reset_index()
    print(d)
    try:
        saveToCsv(d, filePath, "Sum_OriginalUPB_Per_Quarter")
    except:
        print("Sum of Original UPB summary file couldn't be saved. Permission Denied Exception")
        pass

def summary_sum_originalUPB_per_year_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Sum of UPB per year per Quarter': fileData.groupby(["ORIGINATION YEAR","ORIGINATION QUARTER"])["ORIGINAL UPB"].sum()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Sum_OriginalUPB_Per_Year_Per_Quarter")
except:
    print("Sum of Original UPB summary file couldn't be saved. Permission Denied Exception")
    pass
    
def summary_average_originalUPB_per_year_func(fileData,filePath):
    d= pd.DataFrame({'Average_ of UPB per year': fileData.groupby(["ORIGINATION YEAR"])["ORIGINAL UPB"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_OriginalUPB_Per_Year")
except:
    print("Average of Original UPB summary file couldn't be saved. Permission Denied Exception")
    pass  

def summary_average_originalUPB_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of UPB per year': fileData.groupby(["ORIGINATION QUARTER"])["ORIGINAL UPB"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_OriginalUPB_Per_Quarter")
except:
    print("Average of Original UPB summary file couldn't be saved. Permission Denied Exception")
    pass  

def summary_average_originalUPB_per_year_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of UPB per year per quarter': fileData.groupby(["ORIGINATION YEAR","ORIGINATION QUARTER"])["ORIGINAL UPB"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_OriginalUPB_Per_Year_Per_Quarter")
except:
    print("Average of Original UPB summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_creditScore_per_year_func(fileData,filePath):
    d= pd.DataFrame({'Average of Credit Score per year': fileData.groupby(["ORIGINATION YEAR"])["CREDIT SCORE"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_CreditScore_per_year")
except:
    print("Average of Credit Score summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_creditScore_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of Credit Score per year per quarter': fileData.groupby(["ORIGINATION QUARTER"])["CREDIT SCORE"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_CreditScore_Per_Quarter")
except:
    print("Average of Credit Score summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_creditScore_per_year_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of CreditScore per year per quarter': fileData.groupby(["ORIGINATION YEAR","ORIGINATION QUARTER"])["CREDIT SCORE"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_CreditScore_Per_Year_Per_Quarter")
except:
    print("Average of Credit Score summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_CLTV_per_year(fileData,filePath):
    d= pd.DataFrame({'Average of CLTV per year': fileData.groupby(["ORIGINATION YEAR"])["ORIGINAL COMBINED LOAN-TO-VALUE (CLTV)"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_CLTV_per_year")
except:
    print("Average of CLTV per year summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_CLTV_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of CreditScore per year per quarter': fileData.groupby(["ORIGINATION QUARTER"])["ORIGINAL COMBINED LOAN-TO-VALUE (CLTV)"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_CLTV_Per_Quarter")
except:
    print("Average of CLTV Per Quarter summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_CLTV_per_year_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of CLTV per year per quarter': fileData.groupby(["ORIGINATION YEAR","ORIGINATION QUARTER"])["ORIGINAL COMBINED LOAN-TO-VALUE (CLTV)"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_CreditScore_Per_Year_Per_Quarter")
except:
    print("Average of Credit Score summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_LTV_per_year_func(fileData,filePath):
    d= pd.DataFrame({'Average of LTV per year': fileData.groupby(["ORIGINATION YEAR"])["ORIGINAL LOAN-TO-VALUE (LTV)"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_LTV_Per_Year")
except:
    print("Average of LTV per year summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_LTV_per_quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of LTV per quarter': fileData.groupby(["ORIGINATION QUARTER"])["ORIGINAL LOAN-TO-VALUE (LTV)"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_LTV_Per_Quarter")
except:
    print("Average of LTV per quarter summary file couldn't be saved. Permission Denied Exception")
    pass 

def summary_average_LTV_per_year_per_Quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of LTV per year per quarter': fileData.groupby(["ORIGINATION YEAR","ORIGINATION QUARTER"])["ORIGINAL LOAN-TO-VALUE (LTV)"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_LTV_per_year_per_Quarter")
except:
    print("Average of LTV file couldn't be saved. Permission Denied Exception")
    pass 

#Average of Interest Rate per Year
def summary_average_IntererstRate_per_year_func(fileData,filePath):
    d= pd.DataFrame({'Average of Interest Rate per Year': fileData.groupby(["ORIGINATION YEAR"])["ORIGINAL INTEREST RATE"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_Interest_Rate_per_Year")
except:
    print("Average of Interest Rate per year couldn't be saved. Permission Denied Exception")
    pass 

#Average of Interest Rate per Quarter
def summary_average_IntererstRate_per_Quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of LTV per year per quarter': fileData.groupby(["ORIGINATION QUARTER"])["ORIGINAL INTEREST RATE"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_Interest_Rate_per_Quarter")
except:
    print("Average of Interest Rate per Quarter couldn't be saved. Permission Denied Exception")
    pass 

#Average of Interest Rate per year per Quarter
def summary_average_IntererstRate_per_year_per_Quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of Interest Rate per year per quarter': fileData.groupby(["ORIGINATION YEAR","ORIGINATION QUARTER"])["ORIGINAL INTEREST RATE"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_Interest_Rate_per_year_per_Quarter")
except:
    print("Average of Interest Rate per year per quarter couldn't be saved. Permission Denied Exception")
    pass 

#Count of Loans with First Time Home Buyer equal to "Y", Occupancy equal to "I" or "S" and Loan Purpose equal to "C" and "N"
def summary_average_IntererstRate_per_year_per_Quarter_func(fileData,filePath):
    d= pd.DataFrame({'Average of Interest Rate per year per quarter': fileData.groupby(["ORIGINATION YEAR","ORIGINATION QUARTER"])["ORIGINAL INTEREST RATE"].mean()}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Average_Interest_Rate_per_year_per_Quarter")
except:
    print("Average of Interest Rate per year per quarter couldn't be saved. Permission Denied Exception")
    pass 

#Count of Loans with First Time Home Buyer equal to "Y", Occupancy equal to "I" or "S" and Loan Purpose equal to "C" and "N"
def summary_count_of_loans_of_firsttimehomebuyer_OcccupancyIorS_LoanPurposeCorN_func(fileData,filePath):
    d= pd.DataFrame({'Count of Loans with First Time Home Buyer equal to "Y", Occupancy equal to "I" or "S" and Loan Purpose equal to "C" and "N': fileData[(fileData["FIRST TIME HOMEBUYER FLAG"] =='Y') & (summary9["OCCUPANCY STATUS"]=='I') | (summary9["OCCUPANCY STATUS"]=='S') & (summary9["LOAN PURPOSE"]=='C') | (summary9["LOAN PURPOSE"]=='N')]}).reset_index()    
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_Loans_Of_Firsttimehomebuyer_OcccupancyIorS_LoanPurposeCorN")
except:
    print("Count of Loans with First Time Home Buyer equal to 'Y', Occupancy equal to 'I' or 'S' and Loan Purpose equal to 'C' and 'N' couldn't be saved. Permission Denied Exception")
    pass

#Count of Loans with MSA flag equal to "YES"
def summary_count_of_loans_of_with_MSAflagequaltoYES_func(fileData,filePath):
    d1= pd.DataFrame({'Count of Loans with MSA flag equal to "YES"': fileData[(fileData["METROPOLITAN_AREA_FLAG"])]}).reset_index() 
    d = d1["LOAN SEQUENCE NUMBER"].count()
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_Loans_Of_With_MSAflagequaltoYES")
except:
    print("Count of Loans with MSA flag equal to 'YES' couldn't be saved. Permission Denied Exception")
    pass

#Count of Loans with MSA flag equal to "NO"
def summary_count_of_loans_of_with_MSAflagequaltoNO_func(fileData,filePath):
    d1= pd.DataFrame({'Count of Loans with MSA flag equal to "NO"': fileData[(fileData["METROPOLITAN_AREA_FLAG"])]}).reset_index()  
    d = d1["LOAN SEQUENCE NUMBER"].count()
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_Loans_Of_With_MSAflagequaltoNO")
except:
    print("Count of Loans with MSA flag equal to 'NO' couldn't be saved. Permission Denied Exception")
    pass


#Average Original UPB where MSA flag equal to "YES"
def summary_average_of_UPB_where_MSAflagequaltoYES_func(fileData,filePath):
    d1= pd.DataFrame({'Count of UPB with MSA flag equal to "YES"': fileData[(fileData["METROPOLITAN_AREA_FLAG"] =='YES')]}).reset_index()  
    d = d1["ORIGINAL UPB"].mean()
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_UPB_Of_With_MSAflagequaltoYES")
except:
    print("Average of UPB with MSA flag equal to 'YES' couldn't be saved. Permission Denied Exception")
    pass


#Average Original UPB where MSA flag equal to "NO"
def summary_average_of_UPB_where_MSAflagequaltoNO_func(fileData,filePath):
    d1= pd.DataFrame({'Count of UPB with MSA flag equal to "NO"': fileData[(fileData["METROPOLITAN_AREA_FLAG"] =='NO')]}).reset_index()  
    d = d1["ORIGINAL UPB"].mean()
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_UPB_Of_With_MSAflagequaltoYES")
except:
    print("Average of UPB with MSA flag equal to 'NO' couldn't be saved. Permission Denied Exception")
    pass

#Average Credit Score where MSA flag equal to "YES"
def summary_average_of_CreditScore_where_MSAflagequaltoYES_func(fileData,filePath):
    d1= pd.DataFrame({'Count of Credit Score with MSA flag equal to "YES"': fileData[(fileData["METROPOLITAN_AREA_FLAG"] =='YES')]}).reset_index()  
    d = d1["CREDIT SCORE"].mean()
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_CreditScore_With_MSAflagequaltoYES")
except:
    print("Count of Credit Score with MSA flag equal to 'YES' couldn't be saved. Permission Denied Exception")
    pass


#Average Credit Score where MSA flag equal to "NO"
def summary_average_of_CreditScore_where_MSAflagequaltoNO_func(fileData,filePath):
    d1= pd.DataFrame({'Count of Credit Score with MSA flag equal to "NO"': fileData[(fileData["METROPOLITAN_AREA_FLAG"] =='NO')]}).reset_index()  
    d = d1["CREDIT SCORE"].mean()
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_CreditScore_With_MSAflagequaltoYES")
except:
    print("Count of Credit Score with MSA flag equal to 'YES' couldn't be saved. Permission Denied Exception")
    pass

#Average Interest Rate where MSA flag equal to "YES"
def summary_average_of_InterestRate_where_MSAflagequaltoYES_func(fileData,filePath):
    d1= pd.DataFrame({'Count of Interest Rate with MSA flag equal to "YES"': fileData[(fileData["METROPOLITAN_AREA_FLAG"] =='YES')]}).reset_index()  
    d = d1["ORIGINAL INTEREST RATE"].mean()
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_InterestRate_With_MSAflagequaltoYES")
except:
    print("Count of Credit Score with MSA flag equal to 'YES' couldn't be saved. Permission Denied Exception")
    pass

#Average Interest Rate where MSA flag equal to "NO"
def summary_average_of_InterestRate_where_MSAflagequaltoNO_func(fileData,filePath):
    d1= pd.DataFrame({'Count of Interest Rate with MSA flag equal to "NO"': fileData[(fileData["METROPOLITAN_AREA_FLAG"] =='NO')]}).reset_index()  
    d = d1["ORIGINAL INTEREST RATE"].mean()
    print(d)
try:
    saveToCsv(d, filePath, "Count_Of_CreditScore_With_MSAflagequaltoNO")
except:
    print("Count of Credit Score with MSA flag equal to 'YES' couldn't be saved. Permission Denied Exception")
    pass
result13 = summary10[(summary10["METROPOLITAN_AREA_FLAG"] =='NO')]
print(result13["ORIGINAL INTEREST RATE"].mean())


# CODE TO SUMMARIZE THE DATA
summary_sum_originalUPB_per_year_func(fileData,filePath)
summary_sum_originalUPB_per_quarter_func(fileData,filePath)
summary_sum_originalUPB_per_year_per_quarter_func(fileData,filePath)
summary_average_originalUPB_per_year_func(fileData,filePath)
summary_average_originalUPB_per_quarter_func(fileData,filePath)
summary_average_originalUPB_per_year_per_quarter_func(fileData,filePath)
summary_average_creditScore_per_year_func(fileData,filePath)
summary_average_creditScore_per_quarter_func(fileData,filePath)
summary_average_creditScore_per_year_per_quarter_func(fileData,filePath)
summary_average_CLTV_per_year(fileData,filePath)
summary_average_CLTV_per_quarter_func(fileData,filePath)
summary_average_CLTV_per_year_per_quarter_func(fileData,filePath)
summary_average_LTV_per_year_func(fileData,filePath)
summary_average_LTV_per_quarter_func(fileData,filePath)
summary_average_LTV_per_year_per_Quarter_func(fileData,filePath)
summary_average_IntererstRate_per_year_func(fileData,filePath)
summary_average_IntererstRate_per_Quarter_func(fileData,filePath)
summary_average_IntererstRate_per_year_per_Quarter_func(fileData,filePath)
# Out:
# Sum of Original UPB summary file couldn't be saved. Permission Denied Exception
# Average of Original UPB summary file couldn't be saved. Permission Denied Exception
# Average of Original UPB summary file couldn't be saved. Permission Denied Exception
# Average of Original UPB summary file couldn't be saved. Permission Denied Exception
# Average of Credit Score summary file couldn't be saved. Permission Denied Exception
# Average of Credit Score summary file couldn't be saved. Permission Denied Exception
# Average of Credit Score summary file couldn't be saved. Permission Denied Exception
# Average of CLTV per year summary file couldn't be saved. Permission Denied Exception
# Average of CLTV Per Quarter summary file couldn't be saved. Permission Denied Exception
# Average of Credit Score summary file couldn't be saved. Permission Denied Exception
# Average of LTV per year summary file couldn't be saved. Permission Denied Exception
# ...
